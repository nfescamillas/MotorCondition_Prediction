# %%
import os 
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import Xception 
from tensorflow.keras.models import Sequential 
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
# print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

# %%
def load_images(base_dir, target_size):
    images=[]
    labels=[]
    class_names = sorted(os.listdir(base_dir))
    class_names = [ name for name in class_names if name != 'Readme.txt']
    class_mapping ={name :idx for idx,name in enumerate(class_names)}

    for name in class_names:
        folder_path = os.path.join(base_dir, name)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                if file.endswith('bmp'):
                    img_path = os.path.join(folder_path,file)
                    img =Image.open(img_path)
                    img = img.resize((target_size))
                    img = np.asarray(img)
                    
                    images.append(img)
                    labels.append(class_mapping[name])
                
    return np.array(images), np.array(labels), class_mapping

# %%
base_dir = './data' 
target_size = (150,150)

images, labels, class_mapping =load_images(base_dir, target_size)
images = images.astype('float32')/ 255

# %%
class_mapping
# Out:
# {'A10': 0,
#  'A30': 1,
#  'A50': 2,
#  'A_B50': 3,
#  'A_C10': 4,
#  'A_C30': 5,
#  'A_C_B10': 6,
#  'A_C_B30': 7,
#  'Fan': 8,
#  'Noload': 9,
#  'Rotor_0': 10}

# %%
print(labels[100])
plt.imshow(images[100])
plt.show()
# Out:
# 2

# %%
images[100].shape
# Out:
# (150, 150, 3)

# %%
base_model =Xception(weights ='imagenet',include_top=False, input_shape=(150,150,3))
base_model.trainable= False

# %%
def model_arch(model,learning_rate):
    inputs = keras.Input(shape=(150,150,3))
    base = base_model(inputs)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    inner =keras.layers.Dense(100,activation='relu')(vectors)
    outputs =keras.layers.Dense(len(class_mapping), activation='softmax')(inner)
    model =keras.Model(inputs,outputs)
    optimizer =keras.optimizers.Adam(learning_rate=learning_rate)
    loss =keras.losses.CategoricalCrossentropy(from_logits=False)
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
train_image,test_image,train_labels, test_labels = train_test_split(images, labels, test_size=0.2, shuffle=True, random_state=42)
train_labels = to_categorical(train_labels, num_classes=11)
test_labels = to_categorical(test_labels, num_classes=11)

# %%
scores ={}

for lr in [0.0001,0.001,0.01,0.1]:
    model = model_arch(base_model, lr)
    history =model.fit(train_image, train_labels, epochs=10, batch_size=8, validation_split =0.2)
    scores[lr] =history.history
# Out:
# Epoch 1/10
# 30/30 [==============================] - 18s 356ms/step - loss: 2.1683 - accuracy: 0.1186 - val_loss: 1.9611 - val_accuracy: 0.2542
# Epoch 2/10
# 30/30 [==============================] - 7s 243ms/step - loss: 1.8176 - accuracy: 0.3432 - val_loss: 1.7151 - val_accuracy: 0.3898
# Epoch 3/10
# 30/30 [==============================] - 8s 260ms/step - loss: 1.6133 - accuracy: 0.5085 - val_loss: 1.5628 - val_accuracy: 0.4407
# Epoch 4/10
# 30/30 [==============================] - 7s 250ms/step - loss: 1.4525 - accuracy: 0.6314 - val_loss: 1.4139 - val_accuracy: 0.5932
# Epoch 5/10
# 30/30 [==============================] - 7s 244ms/step - loss: 1.3244 - accuracy: 0.6780 - val_loss: 1.3000 - val_accuracy: 0.6780
# Epoch 6/10
# 30/30 [==============================] - 7s 233ms/step - loss: 1.2322 - accuracy: 0.7119 - val_loss: 1.2161 - val_accuracy: 0.7119
# Epoch 7/10
# 30/30 [==============================] - 7s 234ms/step - loss: 1.1445 - accuracy: 0.7415 - val_loss: 1.1426 - val_accuracy: 0.7288
# Epoch 8/10
# 30/30 [==============================] - 7s 235ms/step - loss: 1.0780 - accuracy: 0.7585 - val_loss: 1.0815 - val_accuracy: 0.7458
# Epoch 9/10
# 30/30 [==============================] - 7s 230ms/step - loss: 1.0207 - accuracy: 0.7627 - val_loss: 1.0386 - val_accuracy: 0.7627
# Epoch 10/10
# 30/30 [==============================] - 7s 239ms/step - loss: 0.9750 - accuracy: 0.7627 - val_loss: 0.9979 - val_accuracy: 0.7627
# Epoch 1/10
# 30/30 [==============================] - 29s 401ms/step - loss: 1.7724 - accuracy: 0.4237 - val_loss: 1.1259 - val_accuracy: 0.6610
# Epoch 2/10
# 30/30 [==============================] - 7s 250ms/step - loss: 0.8979 - accuracy: 0.7627 - val_loss: 0.7991 - val_accuracy: 0.7966
# Epoch 3/10
# 30/30 [==============================] - 7s 238ms/step - loss: 0.7152 - accuracy: 0.8771 - val_loss: 0.7205 - val_accuracy: 0.8136
# Epoch 4/10
# 30/30 [==============================] - 7s 241ms/step - loss: 0.6389 - accuracy: 0.9237 - val_loss: 0.6796 - val_accuracy: 0.8136
# Epoch 5/10
# 30/30 [==============================] - 12s 406ms/step - loss: 0.5890 - accuracy: 0.9322 - val_loss: 0.6349 - val_accuracy: 0.8305
# Epoch 6/10
# 30/30 [==============================] - 7s 244ms/step - loss: 0.5525 - accuracy: 0.9364 - val_loss: 0.5946 - val_accuracy: 0.8475
# Epoch 7/10
# 30/30 [==============================] - 7s 241ms/step - loss: 0.5219 - accuracy: 0.9534 - val_loss: 0.5714 - val_accuracy: 0.8475
# Epoch 8/10
# 30/30 [==============================] - 7s 240ms/step - loss: 0.5031 - accuracy: 0.9534 - val_loss: 0.5377 - val_accuracy: 0.8644
# Epoch 9/10
# 30/30 [==============================] - 9s 289ms/step - loss: 0.4841 - accuracy: 0.9534 - val_loss: 0.5259 - val_accuracy: 0.8644
# Epoch 10/10
# 30/30 [==============================] - 8s 256ms/step - loss: 0.4626 - accuracy: 0.9576 - val_loss: 0.5079 - val_accuracy: 0.8644
# Epoch 1/10
# 30/30 [==============================] - 12s 277ms/step - loss: 1.3618 - accuracy: 0.6483 - val_loss: 0.9321 - val_accuracy: 0.7627
# Epoch 2/10
# 30/30 [==============================] - 7s 230ms/step - loss: 0.5399 - accuracy: 0.8347 - val_loss: 0.4117 - val_accuracy: 0.8644
# Epoch 3/10
# 30/30 [==============================] - 7s 242ms/step - loss: 0.3557 - accuracy: 0.9449 - val_loss: 0.4218 - val_accuracy: 0.8475
# Epoch 4/10
# 30/30 [==============================] - 7s 233ms/step - loss: 0.2556 - accuracy: 0.9661 - val_loss: 0.2973 - val_accuracy: 0.9153
# Epoch 5/10
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2248 - accuracy: 0.9534 - val_loss: 0.2935 - val_accuracy: 0.8983
# Epoch 6/10
# 30/30 [==============================] - 7s 239ms/step - loss: 0.1835 - accuracy: 0.9746 - val_loss: 0.2460 - val_accuracy: 0.9492
# Epoch 7/10
# 30/30 [==============================] - 7s 240ms/step - loss: 0.1569 - accuracy: 0.9746 - val_loss: 0.2268 - val_accuracy: 0.9492
# Epoch 8/10
# 30/30 [==============================] - 7s 236ms/step - loss: 0.1378 - accuracy: 0.9788 - val_loss: 0.2610 - val_accuracy: 0.8814
# Epoch 9/10
# 30/30 [==============================] - 8s 256ms/step - loss: 0.1286 - accuracy: 0.9746 - val_loss: 0.2202 - val_accuracy: 0.9153
# Epoch 10/10
# 30/30 [==============================] - 7s 237ms/step - loss: 0.1183 - accuracy: 0.9703 - val_loss: 0.1916 - val_accuracy: 0.9492
# Epoch 1/10
# 30/30 [==============================] - 13s 281ms/step - loss: 20.7921 - accuracy: 0.5424 - val_loss: 4.3785 - val_accuracy: 0.7627
# Epoch 2/10
# 30/30 [==============================] - 7s 250ms/step - loss: 1.6789 - accuracy: 0.8517 - val_loss: 2.2284 - val_accuracy: 0.8305
# Epoch 3/10
# 30/30 [==============================] - 7s 238ms/step - loss: 0.4228 - accuracy: 0.9195 - val_loss: 1.2067 - val_accuracy: 0.8814
# Epoch 4/10
# 30/30 [==============================] - 7s 234ms/step - loss: 0.7647 - accuracy: 0.9068 - val_loss: 1.5203 - val_accuracy: 0.8814
# Epoch 5/10
# 30/30 [==============================] - 7s 239ms/step - loss: 0.3394 - accuracy: 0.9407 - val_loss: 0.5373 - val_accuracy: 0.9322
# Epoch 6/10
# 30/30 [==============================] - 7s 241ms/step - loss: 0.3031 - accuracy: 0.9619 - val_loss: 0.5629 - val_accuracy: 0.9153
# Epoch 7/10
# 30/30 [==============================] - 7s 232ms/step - loss: 0.2654 - accuracy: 0.9619 - val_loss: 1.1028 - val_accuracy: 0.8814
# Epoch 8/10
# 30/30 [==============================] - 7s 228ms/step - loss: 0.0920 - accuracy: 0.9703 - val_loss: 0.7698 - val_accuracy: 0.9153
# Epoch 9/10
# 30/30 [==============================] - 7s 233ms/step - loss: 0.1165 - accuracy: 0.9746 - val_loss: 0.4963 - val_accuracy: 0.9492
# Epoch 10/10
# 30/30 [==============================] - 7s 236ms/step - loss: 0.0347 - accuracy: 0.9915 - val_loss: 0.6695 - val_accuracy: 0.9153

# %%
for lr,hist in scores.items():
    plt.plot(hist['val_accuracy'],label=lr)
plt.legend()
plt.show()

# %%
checkpoint =keras.callbacks.ModelCheckpoint('xception_{epoch:02d}_{val_accuracy:.3f}.h5',
                                            save_best_only= True,
                                            monitor ='val_accuracy',
                                            mode = 'max')

# %%
learning_rate= 0.001

model = model_arch(base_model,learning_rate)
history =model.fit(train_image, train_labels, epochs=10, batch_size=10, validation_split =0.2,callbacks =[checkpoint])
# Out:
# Epoch 1/10
# 24/24 [==============================] - 8s 252ms/step - loss: 1.3285 - accuracy: 0.5127 - val_loss: 0.7708 - val_accuracy: 0.7797
# Epoch 2/10
# 24/24 [==============================] - 5s 218ms/step - loss: 0.6689 - accuracy: 0.8729 - val_loss: 0.6378 - val_accuracy: 0.8305
# Epoch 3/10
# 24/24 [==============================] - 6s 242ms/step - loss: 0.5486 - accuracy: 0.9195 - val_loss: 0.5875 - val_accuracy: 0.8814
# Epoch 4/10
# 24/24 [==============================] - 6s 233ms/step - loss: 0.4938 - accuracy: 0.9576 - val_loss: 0.5170 - val_accuracy: 0.8983
# Epoch 5/10
# 24/24 [==============================] - 6s 242ms/step - loss: 0.4405 - accuracy: 0.9322 - val_loss: 0.4545 - val_accuracy: 0.8814
# Epoch 6/10
# 24/24 [==============================] - 5s 222ms/step - loss: 0.3805 - accuracy: 0.9661 - val_loss: 0.3784 - val_accuracy: 0.9153
# Epoch 7/10
# 24/24 [==============================] - 5s 228ms/step - loss: 0.3281 - accuracy: 0.9576 - val_loss: 0.3365 - val_accuracy: 0.8814
# Epoch 8/10
# 24/24 [==============================] - 5s 219ms/step - loss: 0.2885 - accuracy: 0.9619 - val_loss: 0.2897 - val_accuracy: 0.9322
# Epoch 9/10
# 24/24 [==============================] - 5s 212ms/step - loss: 0.2453 - accuracy: 0.9661 - val_loss: 0.2684 - val_accuracy: 0.8814
# Epoch 10/10
# 24/24 [==============================] - 5s 210ms/step - loss: 0.2127 - accuracy: 0.9661 - val_loss: 0.2633 - val_accuracy: 0.8814

# %%
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  global_average_pooling2d_8   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 11)                22539
#
# =================================================================
# Total params: 20,884,019
# Trainable params: 22,539
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.evaluate(test_image, test_labels, batch_size=8)
# Out:
# 10/10 [==============================] - 4s 304ms/step - loss: 1.8926 - accuracy: 0.9054
# [1.8925526142120361, 0.9054054021835327]
